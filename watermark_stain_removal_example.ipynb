# %% [markdown]
# # Watermark or Stain Remocal
#
# This jupyter notebook demos how to use the ```watermark_removal.py``` module.
# Created by --> Veer Singh at Curl

# %%
import cv2
from modules.watermark_removal import WatermarkRemoval
from IPython.display import Image
import os

# %% [markdown]
# Input parameter: Input image path
#
# Output: Image with watermark/stain removed (numpy array)

# %%
# Input
input_image_path = 'assets/watermark.jpg'

# %%
# Show the image
Image(input_image_path)

# %%
# This will remove the watermark
image_without_watermark = WatermarkRemoval(input_image_path).output()

# %%
# Save the image
cv2.imwrite('output.png', image_without_watermark)
# Out:
# True

# %% [markdown]
# ## Output Image

# %%
# Show the output
Image('Output.png')

# %%
# Delete the Output.png file
os.remove('Output.png')
